# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
true_b = 1
true_w = 2
N = 100
np.random.seed(42)
x = np.random.rand(N, 1)
print(x.shape)
epsilon = (-0.1 * np.random.randn(N, 1))
y_true = true_w * x + true_b + epsilon
y_true
# Out:
# (100, 1)
# array([[1.74037553],
#        [2.93132935],
#        [2.45481181],
#        [2.39607386],
#        [1.33400447],
#        [1.27627778],
#        [0.96837782],
#        [2.78417931],
#        [2.28307938],
#        [2.46632086],
#        [0.94962878],
#        [2.90694459],
#        [2.7178613 ],
#        [1.37335148],
#        [1.35394218],
#        [1.26994452],
#        [1.6786898 ],
#        [2.08227908],
#        [1.90310085],
#        [1.72880978],
#        [2.19409376],
#        [1.25288219],
#        [1.58377795],
#        [1.7561824 ],
#        [2.05367704],
#        [2.61241646],
#        [1.43361902],
#        [2.1086966 ],
#        [2.20095771],
#        [1.05249574],
#        [2.02647111],
#        [1.32359047],
#        [1.10434815],
#        [2.90521567],
#        [3.12314119],
#        [2.61944608],
#        [1.60320452],
#        [0.94902002],
#        [2.38770215],
#        [1.85015025],
#        [1.24754765],
#        [2.10722162],
#        [0.95449476],
# ...
